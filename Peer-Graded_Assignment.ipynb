# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Peer-Graded Assignment: Tools for Data Science

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# My name is **Luis**.
#
# My current occupation is mechanical engineer but my desired one would be to become a Data Scientist.

# %% [markdown]
# *I like Data Science a lot because I enjoy exploring new things and always learning something new. I believe that a career in this field can help me learn a lot about many different topics. I also love maths, statistics and everything related to data visualization. In addition, the current developing of AI and its possibilities (CV, NLP, voice recognition and everything else related to deep learning) make it much more interesting. So, there are many reasons to try to achieve my goal.*

# %% [markdown]
# ### The code below shows the result of printing the addition of 23+25 combined with text on screen

# %%
print('The result of 23+25 is: ',23+25)
# Out:
# The result of 23+25 is:  48

# %% [markdown]
# ### Last task
#
# ----------------------------
# **Bulleted list:**
#
# * Item 1
# * Item 2
# * Item 3
# * Item 4
#
# -----------------------------
#
# **Numbered list:**
#
# 1. Item 1
# 2. Item 2
# 3. Item 3
# 4. Item 4
#
# -----------------------------
#
# **Table:**
#
# | Column 1 | Column 2 |
# |----------|----------|
# | Cell 1,1 | Cell 1,2 |
# | Cell 2,1 | Cell 2,2 |
#
# -----------------------------
#
# **Hiperlink:**
#
# <a href= https://www.coursera.org/ibm> IBM Coursera web </a>
#
# -----------------------------
#
# **Image:**
#
# ![image.png](attachment:e0c4a062-7a5b-4ed3-a9a9-8f7055a055ec.png)
#
# -----------------------------
#
# **Code Highlighting:**
#
# ```
# print('Hello World')
# print('2+4 = ',2+4)
# ```
#
# -----------------------------
#
# **Blockquotes:**
#
# > Example of a blockquote
#
# -----------------------------
#
# **Strikethrough:**
#
# ~~Example of a strikethrough text~~
